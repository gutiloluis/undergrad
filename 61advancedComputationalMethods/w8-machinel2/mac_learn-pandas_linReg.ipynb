# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv("http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv", index_col = 0)
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
data.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4

# %%
data.shape
# Out:
# (200, 4)

# %%
from sklearn.cross_validation import train_test_split
sns.pairplot(data, x_vars=['TV', 'Radio', 'Newspaper'], y_vars='Sales',size = 7, aspect = 0.7, kind = 'reg')

# %%
X = data[['TV','Radio','Newspaper']]
print type(X)
print X.shape
X.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (200, 3)
#       TV  Radio  Newspaper
# 1  230.1   37.8       69.2
# 2   44.5   39.3       45.1
# 3   17.2   45.9       69.3
# 4  151.5   41.3       58.5
# 5  180.8   10.8       58.4

# %%
#The following is equiv to y = data['Sales'] if the name has not spaces
y = data.Sales
print type(y)
print y.shape
y.head()
# Out:
# <class 'pandas.core.series.Series'>
# (200,)
# 1    22.1
# 2    10.4
# 3     9.3
# 4    18.5
# 5    12.9
# Name: Sales, dtype: float64

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

print X_train.shape
print y_train.shape
print X_test.shape
print y_test.shape
# Out:
# (150, 3)
# (150,)
# (50, 3)
# (50,)

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(X_train, y_train)

print linreg.intercept_
print linreg.coef_

print "\n"

print zip(['TV','Radio','Newspaper'],linreg.coef_)
# Out:
# 2.87696662232
# [ 0.04656457  0.17915812  0.00345046]
#
#
# [('TV', 0.046564567874150219), ('Radio', 0.17915812245088844), ('Newspaper', 0.0034504647111804898)]

# %%
y_pred = linreg.predict(X_test)

# %%
from sklearn import metrics
print "Mean absolute error: %f" % (metrics.mean_absolute_error(y_test,y_pred))
print "Mean squared error: %f" % (metrics.mean_squared_error(y_test, y_pred))
print "Root mean squared error: %f" % (np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean absolute error: 1.066892
# Mean squared error: 1.973046
# Root mean squared error: 1.404651

# %%
#Removing newspaper
X_new = data[['TV','Radio']]
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(X_new, y, random_state=1)
linreg.fit(X_train_new, y_train_new)
y_pred_new = linreg.predict(X_test_new)
print np.sqrt(metrics.mean_squared_error(y_test_new, y_pred_new))
# Out:
# 1.38790346994

# %%
#Since it decrased, the feature should be removed from the model.

#Now for the credit cards

# %%
data2 = pd.read_csv("http://www-bcf.usc.edu/~gareth/ISL/Credit.csv", index_col=0)
print data2.shape
data2.head()
# Out:
# (400, 11)
#     Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 1   14.891   3606     283      2   34         11    Male      No     Yes
# 2  106.025   6645     483      3   82         15  Female     Yes     Yes
# 3  104.593   7075     514      4   71         11    Male      No      No
# 4  148.924   9504     681      3   36         11  Female      No      No
# 5   55.882   4897     357      2   68         16    Male      No     Yes
#
#    Ethnicity  Balance
# 1  Caucasian      333
# 2      Asian      903
# 3      Asian      580
# 4      Asian      964
# 5  Caucasian      331

# %%
sns.pairplot(data2, x_vars=['Income','Limit','Rating','Cards','Age','Education'], y_vars='Balance', 
            size=7, aspect=0.7, kind='reg')
